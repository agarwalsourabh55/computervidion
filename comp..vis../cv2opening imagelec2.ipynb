# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img=cv2.imread('puppy.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
#matlpotlib ---> RED,GREEN,BLUE
#OPENCV--->BLUE GREEN RED 

fix_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray=cv2.imread('puppy.jpeg',cv2.IMREAD_GRAYSCALE)

# %%
fix_img.shape
# Out:
# (168, 300, 3)

# %%
img_gray.max()
# Out:
# 255

# %%
plt.imshow(img_gray,cmap='gray') # can use cmap='magma'

# %%
plt.imshow(fix_img)

# %%
new_img=cv2.resize(fix_img,(300,100))

# %%
plt.imshow(new_img)

# %%
w_ratio=0.5
h_ratio=0.5

# %%
new_img=cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
new_img.shape
# Out:
# (84, 150, 3)

# %%
new_img=cv2.flip(fix_img,0)  # flip it along horizontal 0
#flip it along vertical 1
#flip it along bth axis -1
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('total_puppy.jpeg',fix_img)
# Out:
# True

# %%
# if we want to larger the image according to the size of the monitor and itws original dimensions 
# that is called canvas space 
fig=plt.figure(figsize=(10,8))
ax=fig.add_subplot(111)
ax.imshow(fix_img)
