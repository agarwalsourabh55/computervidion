# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
pic=Image.open('puppy.jpeg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr=np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (168, 300, 3)

# %%
 plt.imshow(pic_arr)

# %%
pic_red=pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (168, 300, 3)

# %%
#RGB
#RED channel Values 0-255
#RED channels values 0 no red pure black -255 full red 

plt.imshow(pic_red[:,:,0],cmap='gray')

# %%
plt.imshow(pic_red[:,:,1],cmap='gray')

# %%
 plt.imshow(pic_red[:,:,2],cmap='gray')

# %%
#change green to 0
pic_red[:,:,1]=0

# %%
plt.imshow(pic_red)

# %%
# change red also to 0
pic_red[:,:,0]=0

# %%
plt.imshow(pic_red)
